# %% [markdown]
# # **Reto 2 - EchoNet Dynamic**
# ---
# **Equipo Blue Leg**
#
# Diego Sú Gómez - A01620476
#
# Vanessa Méndez Palacios - A01639925
#
# Estefanía Pérez Yeo - A01639270
#
# Francisco Javier Sanchez Panduro - A01639832
#
# Isaí Abrocio - A01625101

# %% [markdown]
# ## **Importación de librerías**
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from moviepy.editor import VideoFileClip
from IPython.display import display
import cv2
from google.colab.patches import cv2_imshow
import os
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential,Model, load_model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose, Concatenate,concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from keras import backend as K
import matplotlib.patches as patches
from scipy.spatial import ConvexHull
from skimage import measure, draw, filters
from skimage.morphology import binary_dilation, binary_erosion, disk
from scipy.ndimage import gaussian_filter
from skimage.draw import polygon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Carga de archivos .csv con información sobre los videos**
# ---
# El conjunto de datos con el que se va a trabajar en este proyecto es el EchoNet-Dynamic, el cual contiene 10,030 videos de ecocardiogramas de corazones etiquetados. Cada video cuenta con dos frames seleccionados específicamente para entrenamiento de redes neuronales. Un frame es cuando el corazón se encuentra en su tamaño más grande, mientras que otro es cuando el corazón se encuentra en su punto más pequeño. La idea de este dataset es aislar el ventrículo izquierdo de cada uno de los frames, y los archivos contienen coordenadas de dicha máscara.
#
# Adicional a estos videos, el dataset contiene dos archivos .csv, el primero el cual contiene la información de las máscaras para cada uno de los frames, mientras que el segundo contiene el nombre del archivo y el split al que pertenece ese video (Train, Test, Validation).
#
# En este bloque de código se van a cargar ambos archivos .csv para poder estudiarse a fondo y comenzar a comprender el funcionamiento del dataset.

# %%
#Cargar el dataframe
df = pd.read_csv("/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/VolumeTracings.csv")
df.head()
# Out:
#                  FileName         X1         Y1         X2         Y2  Frame
# 0  0X100009310A3BD7FC.avi  51.260417  15.348958  64.932292  69.125000     46
# 1  0X100009310A3BD7FC.avi  50.037611  17.167841  53.367222  16.321330     46
# 2  0X100009310A3BD7FC.avi  49.157378  20.407629  57.090549  18.390722     46
# 3  0X100009310A3BD7FC.avi  48.538173  23.581055  59.997339  20.667707     46
# 4  0X100009310A3BD7FC.avi  47.918968  26.754480  62.904129  22.944693     46

# %%
df.shape
# Out:
# (425010, 6)

# %%
#Carga de archivo de los videos de entrenamiento y validación
df2 = pd.read_csv('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/FileList.csv')
df2.head()
# Out:
#              FileName         EF         ESV         EDV  FrameHeight  \
# 0  0X100009310A3BD7FC  78.498406   14.881368   69.210534          112
# 1  0X1002E8FBACD08477  59.101988   40.383876   98.742884          112
# 2  0X1005D03EED19C65B  62.363798   14.267784   37.909734          112
# 3  0X10075961BC11C88E  54.545097   33.143084   72.914210          112
# 4  0X10094BA0A028EAC3  24.887742  127.581945  169.855024          112
#
#    FrameWidth  FPS  NumberOfFrames  Split
# 0         112   50             174    VAL
# 1         112   50             215  TRAIN
# 2         112   50             104  TRAIN
# 3         112   55             122  TRAIN
# 4         112   52             207    VAL

# %%
df2.shape
# Out:
# (10030, 9)

# %% [markdown]
# ## **Generación de máscara con un archivo**
# ----
# Tras haber cargado los archivos .csv, lo primero que se realizó fue cargar un archivo de video para analizar los frames del mismo, y comenzar a formar las máscaras con los puntos que se encuentran en el DataFrame. A continuación se muestra un ejemplo de la generación de la máscara en base a los puntos obtenidos en el archivo .csv

# %%
#Extraer los frames de la máscara de un archivo
df_archivo = df[df["FileName"]=="0X1A0A263B22CCD966.avi"]
df_archivo.head()
# Out:
#                      FileName         X1         Y1         X2         Y2  \
# 34179  0X1A0A263B22CCD966.avi  46.520833  21.729167  63.656250  65.479167
# 34180  0X1A0A263B22CCD966.avi  46.225063  23.232668  47.790771  22.619432
# 34181  0X1A0A263B22CCD966.avi  45.633521  26.239669  50.330645  24.399962
# 34182  0X1A0A263B22CCD966.avi  45.041980  29.246671  52.870519  26.180493
# 34183  0X1A0A263B22CCD966.avi  44.450439  32.253673  55.410394  27.961023
#
#        Frame
# 34179     72
# 34180     72
# 34181     72
# 34182     72
# 34183     72

# %%
#Extraer los frames específicos para ese archivo
frames = df_archivo["Frame"].unique()
frames
# Out:
# array([72, 83])

# %%
df_archivo["Frame"].value_counts()
# Out:
# 72    21
# 83    21
# Name: Frame, dtype: int64

# %%
#Extraer los frames del archivo
cap = cv2.VideoCapture('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Videos incompletos/0X1A0A263B22CCD966.avi')
frames_imgs = []

# Revisar si está abierto el video
if not cap.isOpened():
    print("Error: No se pudo abrir el archivo.")
else:
    # Encontrar los frames donde están las máscaras
    for frame_number in frames:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number-1)
        ret, frame = cap.read()

        if ret:
            print(f"Frame {frame_number}:")
            frames_imgs.append(frame)
            cv2_imshow(frame)
        else:
            print(f"Error: No se pudo encontrar el frame #{frame_number}.")

    # Mostrar el frame
    cap.release()
# Out:
# Frame 72:
# <PIL.Image.Image image mode=RGB size=112x112>
# Frame 83:
# <PIL.Image.Image image mode=RGB size=112x112>

# %%
# Cargar el video específico
video_folder = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Videos incompletos'
video_filename = '0X1A0A263B22CCD966.avi'

# Obtener los frames que cuentan con las máscaras
frame_72_dataset = df[(df['FileName'] == video_filename) & (df['Frame'] == 72)]
frame_83_dataset = df[(df['FileName'] == video_filename) & (df['Frame'] == 83)]

# Conseguir el video
video_path = os.path.join(video_folder, video_filename)
if not os.path.exists(video_path):
    print(f"Error: Video {video_path} no encontrado.")
else:
    # Abrir el video
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: No se pudo abrir el archivo: {video_path}")
    else:
        cap.set(cv2.CAP_PROP_POS_FRAMES, 71)
        ret, frame_72 = cap.read()

        if not ret:
            print(f"Error: No se pudo extraer el frame 72 de {video_path}")
        else:
            for index, row in frame_72_dataset.iterrows(): #Marcar los puntos
                x, y = int(row['X1']), int(row['Y1'])
                cv2.circle(frame_72, (x, y), 2, (0, 255, 0), -1)
                x2, y2 = int(row['X2']), int(row['Y2'])
                cv2.circle(frame_72, (x2, y2), 2, (0, 255, 0), -1)

        cap.set(cv2.CAP_PROP_POS_FRAMES, 82)
        ret, frame_83 = cap.read()

        if not ret:
            print(f"Error: No se pudo extraer el frame 83 de  {video_path}")
        else:
            for index, row in frame_83_dataset.iterrows():
                x, y = int(row['X1']), int(row['Y1'])
                cv2.circle(frame_83, (x, y), 2, (0, 255, 0), -1)
                x2, y2 = int(row['X2']), int(row['Y2'])
                cv2.circle(frame_83, (x2, y2), 2, (0, 255, 0), -1)

            # Mostrar los frames
            cv2_imshow(frame_72)
            cv2_imshow(frame_83)

        cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=112x112>
# <PIL.Image.Image image mode=RGB size=112x112>

# %% [markdown]
# ## **Generación de máscaras y frames**
# ---
# Tras haber visto como funcionan las coordenadas en relación a los frames obtenidos, se generó una función para poder crear las máscaras de cada uno de los frames por video. Se utilizó el mismo código mostrado previamente, más se añadió la función de guardar tanto el frame como la máscara generada en distintas carpetas almacenadas en Google Drive. Las carpetas fueron organizadas en base al split al que pertenece cada uno de los videos, y la distribución quedó de la siguiente manera.
#
# * Frames Entrenamiento
# * Frames Prueba
# * Frames Validación
# * Máscaras Entrenamiento
# * Máscaras Prueba
# * Máscaras Validación
#
# Después de haber generado estos fólders, se definió una función la cual itera a través de todos los videos del dataset, obtiene los frames en base al archivo .csv, genera las máscaras en base a las coordenadas y luego guarda tanto el frame como la máscara en sus respectivas carpetas dependiendo del split al que pertenecen. Tras haber terminado con este proceso, todos los frames y las máscaras se encuentran guardados en sus respectivas carpetas y se pueden acceder fácilmente sin necesidad de generarlas de nuevo.

# %%
#Obtener los splits de los videos del dataset
df2["Split"].value_counts()
# Out:
# TRAIN    7465
# VAL      1288
# TEST     1277
# Name: Split, dtype: int64

# %%
def mask_generation():
  videos = sorted(os.listdir("/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Videos"))
  for file in videos: #Iterar por los archivos del folder
    if file.endswith(".avi"): #Seleccionar únicamente los videos
      video_name = video_name = file[:-4] #Guardar el nombre del video
      filename = file
      frames = df[df["FileName"] == filename]
      frames = frames["Frame"].unique() #Encontrar los frames de las máscaras

      video_folder = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Videos' #Ruta al folder con todos los videos

      if len(frames) == 2:
        # Obtener los frames que cuentan con las máscaras
        frame_A = df[(df['FileName'] == filename) & (df['Frame'] == frames[0])]
        frame_B = df[(df['FileName'] == filename) & (df['Frame'] == frames[1])]

        #Conseguir el video
        video_path = os.path.join(video_folder, filename)
        if not os.path.exists(video_path):
            print(f"Error: Video {video_path} no encontrado.")
        else:
            # Abrir el video
            cap = cv2.VideoCapture(video_path)

            if not cap.isOpened():
                print(f"Error: No se pudo abrir el archivo: {video_path}")
            else:
                cap.set(cv2.CAP_PROP_POS_FRAMES, frames[0])
                ret, frame_Aimg = cap.read()

                # Obtén las dimensiones del frame
                alto_frame, ancho_frame, _ = frame_Aimg.shape

                # Crea un cuadro negro del mismo tamaño que el frame
                cuadro_negroA = np.zeros((alto_frame, ancho_frame, 3), dtype=np.uint8)
                cuadro_negroA[:] = (0, 0, 0)

                if not ret:
                    print(f"Error: No se pudo extraer el frame de {video_path}")
                else:
                    for index, row in frame_A.iterrows(): #Marcar los puntos
                        x, y = int(row['X1']), int(row['Y1'])
                        x2, y2 = int(row['X2']), int(row['Y2'])
                        cv2.line(cuadro_negroA,(x,y),(x2,y2),(255,255,255),5)

                cap.set(cv2.CAP_PROP_POS_FRAMES, frames[1])
                ret, frame_Bimg = cap.read()

                # Obtén las dimensiones del frame
                alto_frame, ancho_frame, _ = frame_Bimg.shape

                # Crea un cuadro negro del mismo tamaño que el frame
                cuadro_negroB = np.zeros((alto_frame, ancho_frame, 3), dtype=np.uint8)
                cuadro_negroB[:] = (0, 0, 0)

                if not ret:
                    print(f"Error: No se pudo extraer el frame de {video_path}")
                else:
                    for index, row in frame_B.iterrows():
                        x, y = int(row['X1']), int(row['Y1'])
                        x2, y2 = int(row['X2']), int(row['Y2'])
                        cv2.line(cuadro_negroB,(x,y),(x2,y2),(255,255,255),5)

                    # Mostrar los frames
                    # print(f"Frame {frames[0]} de {video_name}:")
                    # cv2_imshow(cuadro_negroA)
                    # print(f"Frame {frames[1]} de {video_name}:")
                    # cv2_imshow(cuadro_negroB)

                    # Especifica la ruta del archivo JPG en la que deseas guardar la máscara
                    split = df2.loc[df2["FileName"] == video_name, "Split"].values[0]
                    if split == "TRAIN":
                      ruta_archivo_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Training'
                    elif split  == "TEST":
                      ruta_archivo_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Test'
                    else:
                      ruta_archivo_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Validation'

                    nombreA = video_name+ '_Frame1' + '.jpg'
                    nombreB = video_name+ '_Frame2' + '.jpg'

                    #print(nombreA,split,ruta_archivo_jpg, ruta_archivo_jpg)
                    #print(nombreB,split,ruta_archivo_jpg, ruta_archivo_jpg)

                    # Guarda la máscara como un archivo JPG
                    cv2.imwrite(os.path.join(ruta_archivo_jpg , nombreA), cuadro_negroA)
                    cv2.imwrite(os.path.join(ruta_archivo_jpg , nombreB), cuadro_negroB)

                    # Verifica si se guardó correctamente
                    if os.path.exists(ruta_archivo_jpg):
                        print(f"La máscara {nombreA} - {nombreB} se ha guardado en {ruta_archivo_jpg}")
                    else:
                        print(f"Error al guardar la máscara en {ruta_archivo_jpg}")


                    # Especifica la ruta del archivo JPG en la que deseas guardar el frame
                    if split == "TRAIN":
                      ruta_archivo_frames_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Training'
                    elif split  == "TEST":
                      ruta_archivo_frames_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Test'
                    else:
                      ruta_archivo_frames_jpg = '/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Validation'


                    nombreA = video_name+ '_Frame1' + '.jpg'
                    nombreB = video_name+ '_Frame2' + '.jpg'

                    #print(nombreA,split,ruta_archivo_frames_jpg)
                    #print(nombreB,split,ruta_archivo_frames_jpg)

                    # Guarda el archivo como un archivo JPG
                    cv2.imwrite(os.path.join(ruta_archivo_frames_jpg , nombreA), frame_Aimg)
                    cv2.imwrite(os.path.join(ruta_archivo_frames_jpg , nombreB), frame_Bimg)

                    # Verifica si se guardó correctamente
                    if os.path.exists(ruta_archivo_jpg):
                        print(f"El frame {nombreA} - {nombreB} se ha guardado en {ruta_archivo_frames_jpg}")
                    else:
                        print(f"Error al guardar el frame en {ruta_archivo_frames_jpg}")

                cap.release()

# %%
#Generar las máscaras y almacenarlas en su respectivo folder
#mask_generation()

# %% [markdown]
# ## **Descarga de las máscaras y frames**
# ---
# Tras haber generado todas las máscaras y haber guardado los frames, se generó una función con el objetivo de seleccionar un directorio y un número específico de frames/máscaras, para poder entrenar un modelo posteriormente. Con esta función generada es muy simple el poder obtener una cantidad específica de frames y máscaras para poder usarlas en el entrenamiento de una red neuronal.
#
# Esta función opera mediante el directorio especificado, se seleccionan los archivos del mismo, y luego se seleccionan únicamente los primeros **N** archivos de la carpeta. Después de haber realizado eso, se normalizan cada una de las imágenes y se guardan en un arreglo para su fácil acceso y manipulación.

# %%
#Función para obtener las imágenes de las máscaras/frames dependiendo de un folder
def get_images(route, number=0):
  list_imgs = []
  names_files = []
  files = sorted(os.listdir(route))
  if number != 0:
    files_number = files[:number]

  #Guardar cada mascara en la lista
  for archivo in files_number:
    #print(archivo)
    if archivo.endswith(".jpg"):
      archivo_mascara = os.path.join(route,archivo)
      mask = cv2.imread(archivo_mascara,cv2.IMREAD_GRAYSCALE)
      mask = mask/255.0
      list_imgs.append(mask)
      names_files.append(archivo)

  list_imgs = np.array(list_imgs)
  return list_imgs, names_files

# %%
#Obtener las máscaras de entrenamiento
lista_mascaras, nombres_mascaras = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Training',2000)

# %%
lista_mascaras.shape
# Out:
# (2000, 112, 112)

# %%
lista_mascaras.dtype
# Out:
# dtype('float64')

# %%
#Normalizar las máscaras para que queden valores binarios (0,1)
lista_mascaras[lista_mascaras < 0.5] = 0.0
lista_mascaras[lista_mascaras >= 0.5] = 1.0

# %%
np.unique(lista_mascaras[0])
# Out:
# array([0., 1.])

# %%
#Obtener los frames de entrenamiento
lista_frames, _ = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Training', 2000)

# %%
lista_frames.shape
# Out:
# (2000, 112, 112)

# %%
lista_frames.dtype
# Out:
# dtype('float64')

# %%
figure, axis = plt.subplots(5,2,figsize=(10,12))
axis = axis.flatten()
img = 0
for i in [0,2,4,6,8]:
  axis[i].imshow(lista_frames[img])
  axis[i].axis("off")
  axis[i+1].imshow(lista_mascaras[img])
  axis[i+1].axis("off")
  img +=1

plt.tight_layout()

# %%
#Guardar las imágenes y frames para conjuntos de validación y testing
mascaras_test, nombres_test = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Test',1000)
frames_test, _ = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Test',1000)
mascaras_val, nombres_val = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Mascaras_Validation',1000)
frames_val, _ = get_images('/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/Frames_Validation',1000)

# %%
#Normalizar las máscaras de testing y de validación para que queden valores binarios
mascaras_test[mascaras_test < 0.5] = 0.0
mascaras_test[mascaras_test >= 0.5] = 1.0
mascaras_val[mascaras_val < 0.5] = 0.0
mascaras_val[mascaras_val >= 0.5] = 1.0

# %%
np.unique(mascaras_test)
# Out:
# array([0., 1.])

# %%
figure, axis = plt.subplots(5,2,figsize=(10,12))
axis = axis.flatten()
img = 0
for i in [0,2,4,6,8]:
  axis[i].imshow(frames_test[img])
  axis[i].axis("off")
  axis[i+1].imshow(mascaras_test[img])
  axis[i+1].axis("off")
  img +=1

plt.tight_layout()

# %%
np.unique(mascaras_val)
# Out:
# array([0., 1.])

# %%
figure, axis = plt.subplots(5,2,figsize=(10,12))
axis = axis.flatten()
img = 0
for i in [0,2,4,6,8]:
  axis[i].imshow(frames_val[img])
  axis[i].axis("off")
  axis[i+1].imshow(mascaras_val[img])
  axis[i+1].axis("off")
  img +=1

plt.tight_layout()

# %% [markdown]
# ## **Entrenamiento de una red neuronal con máscaras**
# ---
# Después de haber descargado los frames y máscaras tanto de entrenamiento como de prueba y validación, lo siguiente que se realizó fue generar la red neuronal para poder realizar predicciones. El primer método que se utilizó fue el de realizar las predicciones en base a las máscaras obtenidas, enviando como entradas los frames con sus respectivas máscaras, y buscando que la salida de la red neuronal sean máscaras similares.
#
# La arquitectura elegida fue la U-Net. La U-Net es una arquitectura de redes neuronales utilizadas para segmentación de imágenes. Está compuesta por dos partes principales: Contracción y expansión. Es una red convolucional la cual va reduciendo la imagen mientras la estira horizontalmente y luego viceversa. Con esto se busca encontrar relaciones entre los valores de entrada y poder empezar a definir criterios para las predicciones.
#
# Esta red fue entrenada con los frames y máscaras de entrenamiento, utilizando como optimizador el Adam, mientras que la función de pérdida fue tanto la "binary crossentropy" y el "mean squared error", estas dos métricas fueron útiles para obtener los resultados más acertados con las máscaras obtenidas. El proceso que se siguió fue el siguiente

# %%
#Generar la U-Net para predecir las máscaras
def unet():
  input = Input((112,112,1))
  conv1 = Conv2D(128, (3,3), activation = 'relu', padding = 'same')(input)
  conv1 = Conv2D(128, (3,3), activation = 'relu', padding = 'same')(conv1)
  pool1 = MaxPooling2D((2,2), strides = 2, padding = 'same')(conv1)
  pool1 = BatchNormalization()(pool1)
  drop1 = Dropout(0.2)(pool1)
  conv2 = Conv2D(256, (3,3), activation = 'relu', padding = 'same')(drop1)
  conv2 = Conv2D(256, (3,3), activation = 'relu', padding = 'same')(conv2)
  pool2 = MaxPooling2D((2,2), strides = 2, padding = 'same')(conv2)
  drop2 = Dropout(0.2)(pool2)

  conv3 = Conv2D(512, (3,3), activation = 'relu', padding = 'same')(drop2)
  conv3 = Conv2D(512, (3,3), activation = 'relu', padding = 'same')(conv3)
  pool3 = MaxPooling2D((2,2), strides = 2, padding = 'same')(conv3)
  pool3 = BatchNormalization()(pool3)
  drop3 = Dropout(0.2)(pool3)

  conv4 = Conv2D(1024, (3,3), activation = 'relu', padding = 'same')(drop3)
  conv4 = Conv2D(1024, (3,3), activation = 'relu', padding = 'same')(conv4)
  pool4 = MaxPooling2D((2,2), strides = 2, padding = 'same')(conv4)
  pool4 = BatchNormalization()(pool4)
  drop4 = Dropout(0.2)(pool4)
  convm = Conv2D(2048, (3,3), activation = 'relu', padding = 'same')(drop4)
  convm = Conv2D(2048, (3,3), activation = 'relu', padding = 'same')(convm)
  tran5 = Conv2DTranspose(512, (2,2), strides = 2, padding = 'valid', activation = 'relu')(convm)
  tran5 = BatchNormalization()(tran5)
  conc5 = Concatenate()([tran5, conv4])
  conv5 = Conv2D(1024, (3,3), activation = 'relu', padding = 'same')(conc5)
  conv5 = Conv2D(1024, (3,3), activation = 'relu', padding = 'same')(conv5)
  drop5 = Dropout(0.1)(conv5)

  tran6 = Conv2DTranspose(256, (2,2), strides = 2, padding = 'valid', activation = 'relu')(drop5)
  tran6 = BatchNormalization()(tran6)
  conc6 = Concatenate()([tran6, conv3])
  conv6 = Conv2D(512, (3,3), activation = 'relu', padding = 'same')(conc6)
  conv6 = Conv2D(512, (3,3), activation = 'relu', padding = 'same')(conv6)
  conv6 = BatchNormalization()(conv6)
  drop6 = Dropout(0.1)(conv6)

  tran7 = Conv2DTranspose(128, (2,2), strides = 2, padding = 'valid', activation = 'relu')(drop6)
  conc7 = Concatenate()([tran7, conv2])
  conv7 = Conv2D(256, (3,3), activation = 'relu', padding = 'same')(conc7)
  conv7 = Conv2D(256, (3,3), activation = 'relu', padding = 'same')(conv7)
  conv7 = BatchNormalization()(conv7)
  drop7 = Dropout(0.1)(conv7)

  tran8 = Conv2DTranspose(64, (2,2), strides = 2, padding = 'valid', activation = 'relu')(drop7)
  conc8 = Concatenate()([tran8, conv1])
  conv8 = Conv2D(128, (3,3), activation = 'relu', padding = 'same')(conc8)
  conv8 = Conv2D(128, (3,3), activation = 'relu', padding = 'same')(conv8)
  conv8 = BatchNormalization()(conv8)
  drop8 = Dropout(0.1)(conv8)
  output = Conv2D(1, (1,1), activation = 'relu', padding = 'same')(drop8)
  model = Model(inputs = input, outputs = output)

  return model

# %%
# Define una función para calcular el coeficiente de Dice
def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

#Definir la función de pérdida del Dice Coefficient
def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

#Calcular la pérdida en base al Dice Coefficient
def combined_loss(y_true, y_pred, alpha=0.5, beta=0.5):
    dice = dice_loss(y_true, y_pred)
    bce = binary_crossentropy(y_true, y_pred)
    return alpha * bce+beta*dice

# %%
#Inicializar la red neuronal
model = unet()

# %%
#Compilar la red neuronal con función de pérdida, optimizador, métricas y épocas
model.compile(loss="mean_squared_error", optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), metrics=["accuracy", dice_coefficient])

# %%
#Guardar el modelo
model.save("model.h5")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Definir un checkpoint para guardar el modelo con la menor pérdida en la validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="model.h5",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    save_weights_only=True,
    verbose=1)

# %%
#Entrenar el modelo
history = model.fit(lista_frames, lista_mascaras, epochs=100, validation_data=(frames_val, mascaras_val), callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.8453 - dice_coefficient: 0.1339
# Epoch 1: val_loss improved from inf to 0.12857, saving model to model.h5
# 63/63 [==============================] - 125s 1s/step - loss: 0.1979 - accuracy: 0.8453 - dice_coefficient: 0.1339 - val_loss: 0.1286 - val_accuracy: 0.8714 - val_dice_coefficient: 2.1925e-05
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.8742 - dice_coefficient: 0.2790
# Epoch 2: val_loss improved from 0.12857 to 0.12696, saving model to model.h5
# 63/63 [==============================] - 70s 1s/step - loss: 0.0969 - accuracy: 0.8742 - dice_coefficient: 0.2790 - val_loss: 0.1270 - val_accuracy: 0.8714 - val_dice_coefficient: 0.0189
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.8855 - dice_coefficient: 0.3694
# Epoch 3: val_loss did not improve from 0.12696
# 63/63 [==============================] - 70s 1s/step - loss: 0.0844 - accuracy: 0.8855 - dice_coefficient: 0.3694 - val_loss: 0.1308 - val_accuracy: 0.8489 - val_dice_coefficient: 0.1526
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.8988 - dice_coefficient: 0.4446
# Epoch 4: val_loss improved from 0.12696 to 0.12102, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0744 - accuracy: 0.8988 - dice_coefficient: 0.4446 - val_loss: 0.1210 - val_accuracy: 0.8715 - val_dice_coefficient: 0.1067
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9256 - dice_coefficient: 0.5841
# Epoch 5: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0559 - accuracy: 0.9256 - dice_coefficient: 0.5841 - val_loss: 0.1278 - val_accuracy: 0.8714 - val_dice_coefficient: 0.0082
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9496 - dice_coefficient: 0.7164
# Epoch 6: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0385 - accuracy: 0.9496 - dice_coefficient: 0.7164 - val_loss: 0.1286 - val_accuracy: 0.8714 - val_dice_coefficient: 5.2053e-05
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9590 - dice_coefficient: 0.7668
# Epoch 7: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0316 - accuracy: 0.9590 - dice_coefficient: 0.7668 - val_loss: 0.1286 - val_accuracy: 0.8714 - val_dice_coefficient: 3.0429e-05
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9638 - dice_coefficient: 0.7940
# Epoch 8: val_loss did not improve from 0.12102
# 63/63 [==============================] - 69s 1s/step - loss: 0.0281 - accuracy: 0.9638 - dice_coefficient: 0.7940 - val_loss: 0.1286 - val_accuracy: 0.8714 - val_dice_coefficient: 1.5230e-04
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9658 - dice_coefficient: 0.8035
# Epoch 9: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0264 - accuracy: 0.9658 - dice_coefficient: 0.8035 - val_loss: 0.1280 - val_accuracy: 0.8714 - val_dice_coefficient: 0.0063
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9686 - dice_coefficient: 0.8211
# Epoch 10: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0240 - accuracy: 0.9686 - dice_coefficient: 0.8211 - val_loss: 0.1285 - val_accuracy: 0.8714 - val_dice_coefficient: 3.1590e-04
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9715 - dice_coefficient: 0.8377
# Epoch 11: val_loss did not improve from 0.12102
# 63/63 [==============================] - 69s 1s/step - loss: 0.0217 - accuracy: 0.9715 - dice_coefficient: 0.8377 - val_loss: 0.1280 - val_accuracy: 0.8714 - val_dice_coefficient: 0.0060
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9730 - dice_coefficient: 0.8451
# Epoch 12: val_loss did not improve from 0.12102
# 63/63 [==============================] - 70s 1s/step - loss: 0.0206 - accuracy: 0.9730 - dice_coefficient: 0.8451 - val_loss: 0.1249 - val_accuracy: 0.8715 - val_dice_coefficient: 0.0326
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9746 - dice_coefficient: 0.8541
# Epoch 13: val_loss improved from 0.12102 to 0.11908, saving model to model.h5
# 63/63 [==============================] - 73s 1s/step - loss: 0.0195 - accuracy: 0.9746 - dice_coefficient: 0.8541 - val_loss: 0.1191 - val_accuracy: 0.8722 - val_dice_coefficient: 0.0856
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9750 - dice_coefficient: 0.8558
# Epoch 14: val_loss improved from 0.11908 to 0.09535, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0189 - accuracy: 0.9750 - dice_coefficient: 0.8558 - val_loss: 0.0954 - val_accuracy: 0.8880 - val_dice_coefficient: 0.3231
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9756 - dice_coefficient: 0.8618
# Epoch 15: val_loss improved from 0.09535 to 0.08745, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0184 - accuracy: 0.9756 - dice_coefficient: 0.8618 - val_loss: 0.0875 - val_accuracy: 0.8953 - val_dice_coefficient: 0.4080
# Epoch 16/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9758 - dice_coefficient: 0.8608
# Epoch 16: val_loss improved from 0.08745 to 0.08043, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0183 - accuracy: 0.9758 - dice_coefficient: 0.8608 - val_loss: 0.0804 - val_accuracy: 0.9029 - val_dice_coefficient: 0.4827
# Epoch 17/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9768 - dice_coefficient: 0.8666
# Epoch 17: val_loss improved from 0.08043 to 0.07815, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0175 - accuracy: 0.9768 - dice_coefficient: 0.8666 - val_loss: 0.0781 - val_accuracy: 0.9083 - val_dice_coefficient: 0.5631
# Epoch 18/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9776 - dice_coefficient: 0.8720
# Epoch 18: val_loss did not improve from 0.07815
# 63/63 [==============================] - 70s 1s/step - loss: 0.0169 - accuracy: 0.9776 - dice_coefficient: 0.8720 - val_loss: 0.0789 - val_accuracy: 0.9082 - val_dice_coefficient: 0.5625
# Epoch 19/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9779 - dice_coefficient: 0.8736
# Epoch 19: val_loss improved from 0.07815 to 0.07651, saving model to model.h5
# 63/63 [==============================] - 72s 1s/step - loss: 0.0167 - accuracy: 0.9779 - dice_coefficient: 0.8736 - val_loss: 0.0765 - val_accuracy: 0.9126 - val_dice_coefficient: 0.6361
# Epoch 20/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9785 - dice_coefficient: 0.8755
# Epoch 20: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0162 - accuracy: 0.9785 - dice_coefficient: 0.8755 - val_loss: 0.0766 - val_accuracy: 0.9112 - val_dice_coefficient: 0.6326
# Epoch 21/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9789 - dice_coefficient: 0.8791
# Epoch 21: val_loss did not improve from 0.07651
# 63/63 [==============================] - 69s 1s/step - loss: 0.0159 - accuracy: 0.9789 - dice_coefficient: 0.8791 - val_loss: 0.0768 - val_accuracy: 0.9114 - val_dice_coefficient: 0.6052
# Epoch 22/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9791 - dice_coefficient: 0.8786
# Epoch 22: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0157 - accuracy: 0.9791 - dice_coefficient: 0.8786 - val_loss: 0.0793 - val_accuracy: 0.9104 - val_dice_coefficient: 0.6352
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9791 - dice_coefficient: 0.8786
# Epoch 23: val_loss did not improve from 0.07651
# 63/63 [==============================] - 69s 1s/step - loss: 0.0158 - accuracy: 0.9791 - dice_coefficient: 0.8786 - val_loss: 0.0799 - val_accuracy: 0.9114 - val_dice_coefficient: 0.6434
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9797 - dice_coefficient: 0.8831
# Epoch 24: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0153 - accuracy: 0.9797 - dice_coefficient: 0.8831 - val_loss: 0.0847 - val_accuracy: 0.9048 - val_dice_coefficient: 0.5097
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9798 - dice_coefficient: 0.8839
# Epoch 25: val_loss did not improve from 0.07651
# 63/63 [==============================] - 69s 1s/step - loss: 0.0153 - accuracy: 0.9798 - dice_coefficient: 0.8839 - val_loss: 0.0813 - val_accuracy: 0.9084 - val_dice_coefficient: 0.6244
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9799 - dice_coefficient: 0.8849
# Epoch 26: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0150 - accuracy: 0.9799 - dice_coefficient: 0.8849 - val_loss: 0.0818 - val_accuracy: 0.9084 - val_dice_coefficient: 0.6399
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9807 - dice_coefficient: 0.8883
# Epoch 27: val_loss did not improve from 0.07651
# 63/63 [==============================] - 68s 1s/step - loss: 0.0145 - accuracy: 0.9807 - dice_coefficient: 0.8883 - val_loss: 0.0785 - val_accuracy: 0.9110 - val_dice_coefficient: 0.6211
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9805 - dice_coefficient: 0.8872
# Epoch 28: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0146 - accuracy: 0.9805 - dice_coefficient: 0.8872 - val_loss: 0.0787 - val_accuracy: 0.9110 - val_dice_coefficient: 0.6244
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9806 - dice_coefficient: 0.8889
# Epoch 29: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0146 - accuracy: 0.9806 - dice_coefficient: 0.8889 - val_loss: 0.0827 - val_accuracy: 0.9085 - val_dice_coefficient: 0.6415
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9813 - dice_coefficient: 0.8925
# Epoch 30: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0141 - accuracy: 0.9813 - dice_coefficient: 0.8925 - val_loss: 0.0810 - val_accuracy: 0.9080 - val_dice_coefficient: 0.6418
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9814 - dice_coefficient: 0.8918
# Epoch 31: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0141 - accuracy: 0.9814 - dice_coefficient: 0.8918 - val_loss: 0.0807 - val_accuracy: 0.9102 - val_dice_coefficient: 0.6398
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9820 - dice_coefficient: 0.8953
# Epoch 32: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0135 - accuracy: 0.9820 - dice_coefficient: 0.8953 - val_loss: 0.0799 - val_accuracy: 0.9111 - val_dice_coefficient: 0.6394
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9821 - dice_coefficient: 0.8977
# Epoch 33: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0134 - accuracy: 0.9821 - dice_coefficient: 0.8977 - val_loss: 0.0776 - val_accuracy: 0.9111 - val_dice_coefficient: 0.6244
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9821 - dice_coefficient: 0.8964
# Epoch 34: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0135 - accuracy: 0.9821 - dice_coefficient: 0.8964 - val_loss: 0.0812 - val_accuracy: 0.9103 - val_dice_coefficient: 0.6465
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9822 - dice_coefficient: 0.8972
# Epoch 35: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0134 - accuracy: 0.9822 - dice_coefficient: 0.8972 - val_loss: 0.0805 - val_accuracy: 0.9093 - val_dice_coefficient: 0.6382
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9822 - dice_coefficient: 0.8979
# Epoch 36: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0132 - accuracy: 0.9822 - dice_coefficient: 0.8979 - val_loss: 0.0799 - val_accuracy: 0.9093 - val_dice_coefficient: 0.6360
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9829 - dice_coefficient: 0.9012
# Epoch 37: val_loss did not improve from 0.07651
# 63/63 [==============================] - 70s 1s/step - loss: 0.0128 - accuracy: 0.9829 - dice_coefficient: 0.9012 - val_loss: 0.0811 - val_accuracy: 0.9102 - val_dice_coefficient: 0.6366
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9825 - dice_coefficient: 0.8989
# Epoch 38: val_loss improved from 0.07651 to 0.07631, saving model to model.h5
# 63/63 [==============================] - 70s 1s/step - loss: 0.0131 - accuracy: 0.9825 - dice_coefficient: 0.8989 - val_loss: 0.0763 - val_accuracy: 0.9115 - val_dice_coefficient: 0.6165
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9827 - dice_coefficient: 0.9000
# Epoch 39: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0130 - accuracy: 0.9827 - dice_coefficient: 0.9000 - val_loss: 0.0804 - val_accuracy: 0.9103 - val_dice_coefficient: 0.6351
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9823 - dice_coefficient: 0.8985
# Epoch 40: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0133 - accuracy: 0.9823 - dice_coefficient: 0.8985 - val_loss: 0.0824 - val_accuracy: 0.9051 - val_dice_coefficient: 0.6238
# Epoch 41/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9818 - dice_coefficient: 0.8953
# Epoch 41: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0137 - accuracy: 0.9818 - dice_coefficient: 0.8953 - val_loss: 0.0807 - val_accuracy: 0.9104 - val_dice_coefficient: 0.6331
# Epoch 42/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9833 - dice_coefficient: 0.9035
# Epoch 42: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0124 - accuracy: 0.9833 - dice_coefficient: 0.9035 - val_loss: 0.0812 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6367
# Epoch 43/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9837 - dice_coefficient: 0.9060
# Epoch 43: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0122 - accuracy: 0.9837 - dice_coefficient: 0.9060 - val_loss: 0.0817 - val_accuracy: 0.9099 - val_dice_coefficient: 0.6481
# Epoch 44/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9837 - dice_coefficient: 0.9056
# Epoch 44: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0122 - accuracy: 0.9837 - dice_coefficient: 0.9056 - val_loss: 0.0801 - val_accuracy: 0.9103 - val_dice_coefficient: 0.6317
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9840 - dice_coefficient: 0.9081
# Epoch 45: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0119 - accuracy: 0.9840 - dice_coefficient: 0.9081 - val_loss: 0.0817 - val_accuracy: 0.9089 - val_dice_coefficient: 0.6388
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9841 - dice_coefficient: 0.9091
# Epoch 46: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0118 - accuracy: 0.9841 - dice_coefficient: 0.9091 - val_loss: 0.0802 - val_accuracy: 0.9101 - val_dice_coefficient: 0.6377
# Epoch 47/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9840 - dice_coefficient: 0.9068
# Epoch 47: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0120 - accuracy: 0.9840 - dice_coefficient: 0.9068 - val_loss: 0.0792 - val_accuracy: 0.9109 - val_dice_coefficient: 0.6257
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9845 - dice_coefficient: 0.9112
# Epoch 48: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0116 - accuracy: 0.9845 - dice_coefficient: 0.9112 - val_loss: 0.0824 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6434
# Epoch 49/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9847 - dice_coefficient: 0.9120
# Epoch 49: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0114 - accuracy: 0.9847 - dice_coefficient: 0.9120 - val_loss: 0.0792 - val_accuracy: 0.9107 - val_dice_coefficient: 0.6359
# Epoch 50/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9847 - dice_coefficient: 0.9110
# Epoch 50: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0115 - accuracy: 0.9847 - dice_coefficient: 0.9110 - val_loss: 0.0817 - val_accuracy: 0.9101 - val_dice_coefficient: 0.6416
# Epoch 51/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9850 - dice_coefficient: 0.9140
# Epoch 51: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0112 - accuracy: 0.9850 - dice_coefficient: 0.9140 - val_loss: 0.0806 - val_accuracy: 0.9101 - val_dice_coefficient: 0.6397
# Epoch 52/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9851 - dice_coefficient: 0.9140
# Epoch 52: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0112 - accuracy: 0.9851 - dice_coefficient: 0.9140 - val_loss: 0.0978 - val_accuracy: 0.9102 - val_dice_coefficient: 0.6283
# Epoch 53/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9845 - dice_coefficient: 0.9111
# Epoch 53: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0115 - accuracy: 0.9845 - dice_coefficient: 0.9111 - val_loss: 0.0842 - val_accuracy: 0.9083 - val_dice_coefficient: 0.6509
# Epoch 54/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9850 - dice_coefficient: 0.9128
# Epoch 54: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0113 - accuracy: 0.9850 - dice_coefficient: 0.9128 - val_loss: 0.0821 - val_accuracy: 0.9097 - val_dice_coefficient: 0.6357
# Epoch 55/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9851 - dice_coefficient: 0.9152
# Epoch 55: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0111 - accuracy: 0.9851 - dice_coefficient: 0.9152 - val_loss: 0.0813 - val_accuracy: 0.9085 - val_dice_coefficient: 0.6411
# Epoch 56/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9855 - dice_coefficient: 0.9164
# Epoch 56: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0108 - accuracy: 0.9855 - dice_coefficient: 0.9164 - val_loss: 0.0807 - val_accuracy: 0.9099 - val_dice_coefficient: 0.6375
# Epoch 57/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9857 - dice_coefficient: 0.9184
# Epoch 57: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0105 - accuracy: 0.9857 - dice_coefficient: 0.9184 - val_loss: 0.0823 - val_accuracy: 0.9103 - val_dice_coefficient: 0.6430
# Epoch 58/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9861 - dice_coefficient: 0.9205
# Epoch 58: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0103 - accuracy: 0.9861 - dice_coefficient: 0.9205 - val_loss: 0.0814 - val_accuracy: 0.9103 - val_dice_coefficient: 0.6355
# Epoch 59/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9863 - dice_coefficient: 0.9224
# Epoch 59: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0101 - accuracy: 0.9863 - dice_coefficient: 0.9224 - val_loss: 0.0816 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6359
# Epoch 60/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9856 - dice_coefficient: 0.9172
# Epoch 60: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0107 - accuracy: 0.9856 - dice_coefficient: 0.9172 - val_loss: 0.0838 - val_accuracy: 0.9090 - val_dice_coefficient: 0.6496
# Epoch 61/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9862 - dice_coefficient: 0.9211
# Epoch 61: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0103 - accuracy: 0.9862 - dice_coefficient: 0.9211 - val_loss: 0.0805 - val_accuracy: 0.9102 - val_dice_coefficient: 0.6279
# Epoch 62/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9867 - dice_coefficient: 0.9241
# Epoch 62: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0098 - accuracy: 0.9867 - dice_coefficient: 0.9241 - val_loss: 0.0816 - val_accuracy: 0.9108 - val_dice_coefficient: 0.6371
# Epoch 63/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9871 - dice_coefficient: 0.9257
# Epoch 63: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0096 - accuracy: 0.9871 - dice_coefficient: 0.9257 - val_loss: 0.0829 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6440
# Epoch 64/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9867 - dice_coefficient: 0.9234
# Epoch 64: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0099 - accuracy: 0.9867 - dice_coefficient: 0.9234 - val_loss: 0.0845 - val_accuracy: 0.9087 - val_dice_coefficient: 0.6508
# Epoch 65/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9872 - dice_coefficient: 0.9268
# Epoch 65: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0095 - accuracy: 0.9872 - dice_coefficient: 0.9268 - val_loss: 0.0814 - val_accuracy: 0.9097 - val_dice_coefficient: 0.6339
# Epoch 66/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9873 - dice_coefficient: 0.9268
# Epoch 66: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0094 - accuracy: 0.9873 - dice_coefficient: 0.9268 - val_loss: 0.0815 - val_accuracy: 0.9101 - val_dice_coefficient: 0.6383
# Epoch 67/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9874 - dice_coefficient: 0.9277
# Epoch 67: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0094 - accuracy: 0.9874 - dice_coefficient: 0.9277 - val_loss: 0.0820 - val_accuracy: 0.9097 - val_dice_coefficient: 0.6292
# Epoch 68/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9869 - dice_coefficient: 0.9260
# Epoch 68: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0097 - accuracy: 0.9869 - dice_coefficient: 0.9260 - val_loss: 0.0839 - val_accuracy: 0.9092 - val_dice_coefficient: 0.6473
# Epoch 69/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9875 - dice_coefficient: 0.9276
# Epoch 69: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0093 - accuracy: 0.9875 - dice_coefficient: 0.9276 - val_loss: 0.0813 - val_accuracy: 0.9096 - val_dice_coefficient: 0.6374
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9881 - dice_coefficient: 0.9320
# Epoch 70: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0088 - accuracy: 0.9881 - dice_coefficient: 0.9320 - val_loss: 0.0823 - val_accuracy: 0.9098 - val_dice_coefficient: 0.6338
# Epoch 71/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9883 - dice_coefficient: 0.9333
# Epoch 71: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0086 - accuracy: 0.9883 - dice_coefficient: 0.9333 - val_loss: 0.0814 - val_accuracy: 0.9101 - val_dice_coefficient: 0.6291
# Epoch 72/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9864 - dice_coefficient: 0.9216
# Epoch 72: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0103 - accuracy: 0.9864 - dice_coefficient: 0.9216 - val_loss: 0.0836 - val_accuracy: 0.9080 - val_dice_coefficient: 0.6157
# Epoch 73/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9857 - dice_coefficient: 0.9188
# Epoch 73: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0106 - accuracy: 0.9857 - dice_coefficient: 0.9188 - val_loss: 0.0821 - val_accuracy: 0.9085 - val_dice_coefficient: 0.6322
# Epoch 74/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9874 - dice_coefficient: 0.9279
# Epoch 74: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0093 - accuracy: 0.9874 - dice_coefficient: 0.9279 - val_loss: 0.0828 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6394
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9883 - dice_coefficient: 0.9336
# Epoch 75: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0086 - accuracy: 0.9883 - dice_coefficient: 0.9336 - val_loss: 0.0837 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6410
# Epoch 76/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9887 - dice_coefficient: 0.9355
# Epoch 76: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0083 - accuracy: 0.9887 - dice_coefficient: 0.9355 - val_loss: 0.0825 - val_accuracy: 0.9100 - val_dice_coefficient: 0.6420
# Epoch 77/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9890 - dice_coefficient: 0.9368
# Epoch 77: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0082 - accuracy: 0.9890 - dice_coefficient: 0.9368 - val_loss: 0.0832 - val_accuracy: 0.9100 - val_dice_coefficient: 0.6451
# Epoch 78/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9891 - dice_coefficient: 0.9359
# Epoch 78: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0083 - accuracy: 0.9891 - dice_coefficient: 0.9359 - val_loss: 0.0824 - val_accuracy: 0.9104 - val_dice_coefficient: 0.6339
# Epoch 79/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9894 - dice_coefficient: 0.9398
# Epoch 79: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0078 - accuracy: 0.9894 - dice_coefficient: 0.9398 - val_loss: 0.0824 - val_accuracy: 0.9100 - val_dice_coefficient: 0.6338
# Epoch 80/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9897 - dice_coefficient: 0.9412
# Epoch 80: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0076 - accuracy: 0.9897 - dice_coefficient: 0.9412 - val_loss: 0.0830 - val_accuracy: 0.9099 - val_dice_coefficient: 0.6303
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9897 - dice_coefficient: 0.9419
# Epoch 81: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0076 - accuracy: 0.9897 - dice_coefficient: 0.9419 - val_loss: 0.0830 - val_accuracy: 0.9086 - val_dice_coefficient: 0.6368
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9899 - dice_coefficient: 0.9422
# Epoch 82: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0075 - accuracy: 0.9899 - dice_coefficient: 0.9422 - val_loss: 0.0842 - val_accuracy: 0.9098 - val_dice_coefficient: 0.6431
# Epoch 83/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9903 - dice_coefficient: 0.9446
# Epoch 83: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0071 - accuracy: 0.9903 - dice_coefficient: 0.9446 - val_loss: 0.0835 - val_accuracy: 0.9098 - val_dice_coefficient: 0.6378
# Epoch 84/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9904 - dice_coefficient: 0.9452
# Epoch 84: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0071 - accuracy: 0.9904 - dice_coefficient: 0.9452 - val_loss: 0.0837 - val_accuracy: 0.9094 - val_dice_coefficient: 0.6383
# Epoch 85/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9907 - dice_coefficient: 0.9464
# Epoch 85: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0069 - accuracy: 0.9907 - dice_coefficient: 0.9464 - val_loss: 0.0846 - val_accuracy: 0.9096 - val_dice_coefficient: 0.6412
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9907 - dice_coefficient: 0.9467
# Epoch 86: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0069 - accuracy: 0.9907 - dice_coefficient: 0.9467 - val_loss: 0.0833 - val_accuracy: 0.9105 - val_dice_coefficient: 0.6376
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9909 - dice_coefficient: 0.9484
# Epoch 87: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0068 - accuracy: 0.9909 - dice_coefficient: 0.9484 - val_loss: 0.0851 - val_accuracy: 0.9084 - val_dice_coefficient: 0.6400
# Epoch 88/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9911 - dice_coefficient: 0.9490
# Epoch 88: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0066 - accuracy: 0.9911 - dice_coefficient: 0.9490 - val_loss: 0.0839 - val_accuracy: 0.9098 - val_dice_coefficient: 0.6352
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9911 - dice_coefficient: 0.9499
# Epoch 89: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0066 - accuracy: 0.9911 - dice_coefficient: 0.9499 - val_loss: 0.0832 - val_accuracy: 0.9099 - val_dice_coefficient: 0.6299
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9914 - dice_coefficient: 0.9508
# Epoch 90: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0063 - accuracy: 0.9914 - dice_coefficient: 0.9508 - val_loss: 0.0848 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6395
# Epoch 91/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9917 - dice_coefficient: 0.9535
# Epoch 91: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0061 - accuracy: 0.9917 - dice_coefficient: 0.9535 - val_loss: 0.0845 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6428
# Epoch 92/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9917 - dice_coefficient: 0.9526
# Epoch 92: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0061 - accuracy: 0.9917 - dice_coefficient: 0.9526 - val_loss: 0.0847 - val_accuracy: 0.9099 - val_dice_coefficient: 0.6424
# Epoch 93/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9919 - dice_coefficient: 0.9537
# Epoch 93: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0059 - accuracy: 0.9919 - dice_coefficient: 0.9537 - val_loss: 0.0853 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6420
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9920 - dice_coefficient: 0.9546
# Epoch 94: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0059 - accuracy: 0.9920 - dice_coefficient: 0.9546 - val_loss: 0.0841 - val_accuracy: 0.9095 - val_dice_coefficient: 0.6309
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9916 - dice_coefficient: 0.9524
# Epoch 95: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0063 - accuracy: 0.9916 - dice_coefficient: 0.9524 - val_loss: 0.0847 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6351
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9918 - dice_coefficient: 0.9531
# Epoch 96: val_loss did not improve from 0.07631
# 63/63 [==============================] - 69s 1s/step - loss: 0.0060 - accuracy: 0.9918 - dice_coefficient: 0.9531 - val_loss: 0.0848 - val_accuracy: 0.9088 - val_dice_coefficient: 0.6395
# Epoch 97/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9921 - dice_coefficient: 0.9542
# Epoch 97: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0059 - accuracy: 0.9921 - dice_coefficient: 0.9542 - val_loss: 0.0869 - val_accuracy: 0.9095 - val_dice_coefficient: 0.6483
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9923 - dice_coefficient: 0.9562
# Epoch 98: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0057 - accuracy: 0.9923 - dice_coefficient: 0.9562 - val_loss: 0.0853 - val_accuracy: 0.9086 - val_dice_coefficient: 0.6381
# Epoch 99/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9926 - dice_coefficient: 0.9578
# Epoch 99: val_loss did not improve from 0.07631
# 63/63 [==============================] - 68s 1s/step - loss: 0.0055 - accuracy: 0.9926 - dice_coefficient: 0.9578 - val_loss: 0.0876 - val_accuracy: 0.9085 - val_dice_coefficient: 0.6492
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9928 - dice_coefficient: 0.9595
# Epoch 100: val_loss did not improve from 0.07631
# 63/63 [==============================] - 70s 1s/step - loss: 0.0053 - accuracy: 0.9928 - dice_coefficient: 0.9595 - val_loss: 0.0858 - val_accuracy: 0.9089 - val_dice_coefficient: 0.6458

# %%
#Graficar la precisión obtenida con el entrenamiento vs la precisión durante la validación
plt.plot(history.history["accuracy"], label="accuracy", color="blue")
plt.plot(history.history["val_accuracy"], label="val_accuracy", color="green")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy a través de las épocas")
plt.legend()
plt.ylim([0.5,1])
# Out:
# (0.5, 1.0)

# %%
#Guardar el modelo óptimo ya entrenado
model.save("model.h5")

# %% [markdown]
# Tras haber entrenado el modelo con las máscaras, se descargó para evitar el re-entrenamiento y poder realizar las predicciones sin necesidad de entrenar el modelo de nuevo. El modelo ya entrenado se guardó en el mismo Google Drive y se puede acceder de forma fácil.

# %%
#Guardar el Dice coefficient para el modelo descargado
custom_objects = {'dice_coefficient': dice_coefficient}

# %%
#Cargar el modelo ya entrenado
modelo1 = load_model("/content/drive/Shareddrives/TC2007B Team 2 Bravo/Blue Leg/ModelMasks.h5", custom_objects=custom_objects)

# %%
#Realizar las predicciones
predicciones = modelo1.predict(frames_test[:20])
# Out:
# 1/1 [==============================] - 13s 13s/step

# %%
#predicciones_b = np.where(predicciones > 0.5, 1, 0)

# %%
#Mostrar los resultados de la red neuronal comparándolos con la máscara y el frame original
plt.figure(figsize=(20,90))
i = 0
x = 0
while i < 30:
  plt.subplot(15,3,i+1)
  plt.imshow(frames_test[x], cmap="gray")
  plt.title("Imagen real")
  plt.axis("off")

  plt.subplot(15,3,i+2)
  plt.imshow(mascaras_test[x], cmap="gray")
  plt.title("Máscara real")
  plt.axis("off")

  plt.subplot(15,3,i+3)
  plt.imshow(predicciones[x], cmap="gray")
  plt.title("Predicción")
  plt.axis("off")

  i+=3
  x+=1

# %% [markdown]
# ## **Entrenamiento de una red neuronal utilizando landmarks**
# ---
# Después de haber entrenado la U-Net en base a las máscaras obtenidas, se decidió también tomar otro approach distinto. Además de haber formado las máscaras, lo siguiente que se hizo fue usar las máscaras para generar landmarks, que constan de puntos clave alrededor de cada una de las máscaras, para generar 8 landmarks alrededor de la silueta de cada máscara. Con estos landmarks definidos, se generaron imágenes de 8 canales, en donde cada canal consta de un punto específico, y se entrenará la misma arquitectura con la intención de que al entrenar se genere cada landmark en cada uno de los canales, para después formar la máscara resultante.

# %%
#Generar los landmarks de cada una de las máscaras y guardarlas en imágenes (112,112,8)
def generate_landmarks(masks):
  landmarks = []

  for mask in masks:
    contours = measure.find_contours(mask, 0.5)
    idx = np.linspace(0, len(contours[0])-1, 18, dtype=int)
    points = contours[0][idx]
    image = np.zeros((112,112,10))
    for i in range(10):
      si = i * 2 % 18
      ei = (i * 2 + 1) % 18
      x, y = draw.line(int(points[si][0]), int(points[si][1]), int(points[ei][0]), int(points[ei][1]))
      image[x,y,i] = 1.0
      image[:,:,i] = binary_dilation(image[:,:,i], disk(1))
      image[:,:,i] = filters.gaussian(image[:,:,i], sigma=1)

    maxv = np.max(image, axis=(0,1))
    image = image / maxv[np.newaxis, np.newaxis, :]
    #image = np.sum(image, axis=2)
    landmarks.append(image)

  landmarks = np.array(landmarks)
  return landmarks

# %%
#Definir los landmarks de entrenamiento
landmarks_train = generate_landmarks(lista_mascaras)

# %%
landmarks_train.shape
# Out:
# (2000, 112, 112, 8)

# %%
#Mostrar cada landmark en cada uno de los canales de la imagen
img = landmarks_train[15]
num_channels = img.shape[2]

fig, axes = plt.subplots(2, 5, figsize=(12, 6))

for i in range(num_channels):
    row = i // 5
    col = i % 5
    channel_image = img[:, :, i]
    axes[row, col].imshow(channel_image, cmap='gray')
    axes[row, col].set_title(f'Channel {i}')
    axes[row, col].axis('off')

# %%
img = np.sum(img, axis = 2)
plt.imshow(img, cmap="gray")

# %%
#Generar los landmarks de validación
landmarks_val = generate_landmarks(mascaras_val)

# %%
landmarks_val.shape
# Out:
# (1000, 112, 112, 8)

# %%
#Generar los landmarks de prueba
landmarks_test = generate_landmarks(mascaras_test)

# %%
landmarks_test.shape
# Out:
# (1000, 112, 112, 8)

# %%
#Generar la U-Net para predecir los landmarks
def unet_landmarks():
    inputs = Input(shape=(112,112,1))

    conv1 = Conv2D(128, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(128, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = BatchNormalization()(pool1)
    drop1 = Dropout(0.2)(pool1)
    conv2 = Conv2D(256, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(256, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    drop2 = Dropout(0.2)(pool2)

    conv3 = Conv2D(512, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(512, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = BatchNormalization()(pool3)
    drop3 = Dropout(0.2)(pool3)

    conv4 = Conv2D(1024, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(1024, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.2)(conv4)
    up5 = UpSampling2D(size=(2, 2))(conv4)
    concat5 = Concatenate()([conv3, up5])
    conv5 = Conv2D(512, 3, activation='relu', padding='same')(concat5)
    conv5 = Conv2D(512, 3, activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.1)(conv5)

    up6 = UpSampling2D(size=(2, 2))(conv5)
    concat6 = Concatenate()([conv2, up6])
    conv6 = Conv2D(256, 3, activation='relu', padding='same')(concat6)
    conv6 = Conv2D(256, 3, activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    drop6 = Dropout(0.1)(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    concat7 = Concatenate()([conv1, up7])
    conv7 = Conv2D(128, 3, activation='relu', padding='same')(concat7)
    conv7 = Conv2D(128, 3, activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    drop7 = Dropout(0.1)(conv7)

    output = Conv2D(8, 1, activation='sigmoid', padding='same')(conv7)
    model = Model(inputs=inputs, outputs=output)

    return model

# %%
#Cargar la red neuronal
model2 = unet_landmarks()

# %%
#Guardar el modelo para descargarlo
model2.save("model_landmarks.h5")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Entrenar el modelo
model2.compile(loss="mean_squared_error", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
#Definir un checkpoint para guardar el modelo con mejores resultados
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="model_landmarks.h5",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    save_weights_only=True,
    verbose=1)

# %%
history2 = model2.fit(lista_frames, landmarks_train, epochs=100, validation_data=(frames_val, landmarks_val), callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1177
# Epoch 1: val_loss improved from inf to 0.98378, saving model to model_landmarks.h5
# 63/63 [==============================] - 102s 1s/step - loss: 0.1177 - val_loss: 0.9838
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 2: val_loss improved from 0.98378 to 0.00193, saving model to model_landmarks.h5
# 63/63 [==============================] - 56s 897ms/step - loss: 0.0361 - val_loss: 0.0019
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 3: val_loss improved from 0.00193 to 0.00183, saving model to model_landmarks.h5
# 63/63 [==============================] - 53s 843ms/step - loss: 0.0191 - val_loss: 0.0018
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 4: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 830ms/step - loss: 0.0076 - val_loss: 0.0018
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 5: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 6: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 827ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 7: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 873ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 8: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 9: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 10: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 12: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 828ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 13: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 828ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 14: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 874ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 15: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 16/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 16: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 17/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 17: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 18/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 18: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 19/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 19: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 20/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 20: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 21/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 21: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 22/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 22: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 23: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 24: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 827ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 25: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 26: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 27: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 28: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 828ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 29: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 30: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 31: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 828ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 32: val_loss improved from 0.00183 to 0.00183, saving model to model_landmarks.h5
# 63/63 [==============================] - 56s 890ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 33: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 874ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 35: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 36: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 37: val_loss did not improve from 0.00183
# 63/63 [==============================] - 52s 830ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 38: val_loss improved from 0.00183 to 0.00183, saving model to model_landmarks.h5
# 63/63 [==============================] - 58s 917ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 39: val_loss did not improve from 0.00183
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 40: val_loss improved from 0.00183 to 0.00182, saving model to model_landmarks.h5
# 63/63 [==============================] - 57s 914ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 41/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 41: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 42/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 42: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 43/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 43: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 875ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 44/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 44: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 45: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 874ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 46: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 47/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 47: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 48: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 49/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 49: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 875ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 50/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 50: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 51/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 51: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 52/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 52: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 53/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 53: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 54/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 54: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 830ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 55/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 55: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 875ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 56/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 56: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 57/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 57: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 875ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 58/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 58: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 59/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 59: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 60/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 60: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 878ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 61/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 61: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 62/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 62: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 63/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 63: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 64/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 64: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 65/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 65: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 66/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 66: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 67/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 67: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 68/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 68: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 69/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 69: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 878ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 70: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 878ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 71/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 71: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 72/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 72: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 73/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 73: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 74/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 74: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 75: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 829ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 76/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 76: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 77/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 77: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 78/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 78: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 79/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 79: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 80/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 80: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 876ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 81: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 834ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 82: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 831ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 83/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 83: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 84/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 84: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 879ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 85/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 85: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 833ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 86: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 878ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 87: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 834ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 88/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 88: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 877ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 89: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 834ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 90: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 830ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 91/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 91: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 881ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 92/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 92: val_loss did not improve from 0.00182
# 63/63 [==============================] - 53s 835ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 93/100
# 63/63 [==============================] - ETA: 0s - loss: 9.9363e-04
# Epoch 93: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 9.9363e-04 - val_loss: 0.0021
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 9.4625e-04
# Epoch 94: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 831ms/step - loss: 9.4625e-04 - val_loss: 0.0025
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 9.2474e-04
# Epoch 95: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 880ms/step - loss: 9.2474e-04 - val_loss: 0.0022
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 8.6918e-04
# Epoch 96: val_loss did not improve from 0.00182
# 63/63 [==============================] - 53s 836ms/step - loss: 8.6918e-04 - val_loss: 0.0022
# Epoch 97/100
# 63/63 [==============================] - ETA: 0s - loss: 8.2589e-04
# Epoch 97: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 832ms/step - loss: 8.2589e-04 - val_loss: 0.0023
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 8.1397e-04
# Epoch 98: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 877ms/step - loss: 8.1397e-04 - val_loss: 0.0026
# Epoch 99/100
# 63/63 [==============================] - ETA: 0s - loss: 7.5070e-04
# Epoch 99: val_loss did not improve from 0.00182
# 63/63 [==============================] - 52s 835ms/step - loss: 7.5070e-04 - val_loss: 0.0022
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 7.0236e-04
# Epoch 100: val_loss did not improve from 0.00182
# 63/63 [==============================] - 55s 878ms/step - loss: 7.0236e-04 - val_loss: 0.0025

# %%
1#Graficar la pérdida obtenida con el entrenamiento vs la pérdida durante la validación
plt.plot(history2.history["loss"], label="loss", color="blue")
plt.plot(history2.history["val_loss"], label="val_loss", color="green")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Validation Loss a través de las épocas")
plt.legend()

# %%
#Generar las predicciones
predicciones = model2.predict(frames_test[:20])
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
predicciones.shape
# Out:
# (20, 112, 112, 8)

# %%
#Definir una función para formar la máscara en base a los landmarks
def process_landmarks(landmarks):
  masks = []

  for i in range(len(landmarks)):
    image = landmarks[i]
    mask = np.zeros_like(image)
    #Encontrar el valor más grande en cada uno de los canales y guardarlo en la imagen nueva
    for ch in range(8):
      idx = np.unravel_index(np.argmax(image[:,:,ch]), image[:,:,ch].shape)
      mask[idx[0], idx[1], ch] = 255.0

    #Juntar todos los canales en uno solo
    mask = np.sum(mask, axis=2)
    points = np.argwhere(mask == 255.0)
    hull = ConvexHull(points) #Formar la máscara
    mask = np.zeros_like(mask, dtype=np.uint8)
    cv2.polylines(mask, [hull.points[hull.vertices].astype(int)], isClosed=True, color=255, thickness=1)
    cv2.fillPoly(mask, [hull.points[hull.vertices].astype(int)], color=255)
    mask = np.rot90(mask, k=-1) #Postprocesamiento de la máscara formada
    mask = np.fliplr(mask)
    masks.append(mask)

  return masks

# %%
predicciones = process_landmarks(predicciones)

# %%
plt.figure(figsize=(20,90))
i = 0
x = 0
while i < 30:
  plt.subplot(15,3,i+1)
  plt.imshow(frames_test[x], cmap="gray")
  plt.title("Imagen real")
  plt.axis("off")

  plt.subplot(15,3,i+2)
  plt.imshow(mascaras_test[x], cmap="gray")
  plt.title("Máscara real")
  plt.axis("off")

  plt.subplot(15,3,i+3)
  plt.imshow(predicciones[x], cmap="gray")
  plt.title("Predicción")
  plt.axis("off")

  i+=3
  x+=1
